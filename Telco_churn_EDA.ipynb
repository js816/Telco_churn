# %%
# Loading in the dependencies
import pandas as pd

# %%
# Originally found here:  https://www.kaggle.com/blastchar/telco-customer-churn
# Dataset source: 11.1.3 @ https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2018/09/12/base-samples-for-ibm-cognos-analytics
# Details of the meaning of the features are here https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113

# %% [markdown]
# # Updated dataset

# %%
# Loading in dataset as dataframe
df = pd.read_excel('Resources/CustomerChurn.xlsx')
df
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 4        503388  9237-HQITU             No      No         No       2
# ...         ...         ...            ...     ...        ...     ...
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# ...

# %%
# Looking at the shape of the data seems like the two datasets may be the same.  Moving forward with the Excel file

# %%
# Looking at the features
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
# Looking at various columns value counts
df['Total Charges'].value_counts()
# Out:
# 20.2      11
#           11
# 19.75      9
# 19.65      8
# 19.9       8
#           ..
# 3778       1
# 733.35     1
# 280.4      1
# 2954.5     1
# 521        1
# Name: Total Charges, Length: 6531, dtype: int64

# %%
# Looking at the summary statistics of tenure
df['Tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure, dtype: float64

# %%
# Looking at the summary statistics of monthly charges
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
# Looking at summary statistics for total charges
df['Total Charges'].describe()
# Out:
# count     7043.0
# unique    6531.0
# top         20.2
# freq        11.0
# Name: Total Charges, dtype: float64

# %%
# Looking at datatypes
df.dtypes
# Out:
# LoyaltyID              int64
# Customer ID           object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure                 int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn                 object
# dtype: object

# %%
# Noting that some values for Total Charges are blank

# %%
# Looking for null values
df.isnull().sum()
# Out:
# LoyaltyID            0
# Customer ID          0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
# Creating a density plot for tenure
df['Tenure'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Creating a density plot for monthly charges
df['Monthly Charges'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Looking at the output - Churn meaning the customer left the company during the quarter
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# What's unclear here?  Why some of the total charges are missing, which is outside my control
# More importantly, what should I do about it?
missing_total_charges_df = df.loc[df['Total Charges'] == " "]
missing_total_charges_df
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 488      344543  4472-LVYGI             No     Yes        Yes       0
# 753      150036  3115-CZMZD             No      No        Yes       0
# 936      497688  5709-LVOEQ             No     Yes        Yes       0
# 1082     158969  4367-NUYAO             No     Yes        Yes       0
# 1340     470044  1371-DWPAZ             No     Yes        Yes       0
# 3331     937662  7644-OMVMY             No     Yes        Yes       0
# 3826     821083  3213-VVOLG             No     Yes        Yes       0
# 4380     947028  2520-SGTTA             No     Yes        Yes       0
# 5218     135257  2923-ARZLG             No     Yes        Yes       0
# 6670     317862  4075-WKNIU             No     Yes        Yes       0
# 6754     392646  2775-SEFEE             No      No        Yes       0
#
#      Phone Service    Multiple Lines Internet Service      Online Security  \
# ...

# %%
# Looking at summary statistics for those customer's monthly charges
missing_total_charges_df['Monthly Charges'].describe()
# Out:
# count    11.000000
# mean     41.418182
# std      23.831484
# min      19.700000
# 25%      20.125000
# 50%      25.750000
# 75%      58.975000
# max      80.850000
# Name: Monthly Charges, dtype: float64

# %%
# Since the number of customers with Monthly Charges missing is so small, I'm dropping those rows from the
# cleaned DataFrame before proceeding
clean_df = df.loc[df['Total Charges'] != " "]
clean_df
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 4        503388  9237-HQITU             No      No         No       2
# ...         ...         ...            ...     ...        ...     ...
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# ...

# %%
# Setting up the database and table in Postgresql

# %%
# Saving clean_df as csv
clean_df.to_csv('Resources/clean_churn_data.csv', index=False)
